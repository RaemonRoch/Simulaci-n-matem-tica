# %% [markdown]
# # Tarea - Caminata aleatoria

# %% [markdown]
# #### 1. Simulación del movimiento browniano
#
# El movimiento browniano es el movimiento aleatorio que se observa en las partículas que se hallan en un medio fluido, como resultado de choques contra las moléculas de dicho fluido [(referencia)].
#
# [(referencia)]: https://es.wikipedia.org/wiki/Movimiento_browniano
#
# Para simular el movimiento, en lugar de usar las ecuaciones integro-diferenciales que describe Einstein, use una caminta aleatoria para los tres ejes $x$, $y$, $z$ de la siguiente forma
# $$
# W_i=W_{i-1}+X_i\sqrt{\Delta t}
# $$
# donde, $\Delta t$ es un intervalo de tiempo y
# $$
# X_i=\left\{\begin{array}{l}
# 1\\
# -1
# \end{array}\right.,
# $$
# se escoge de forma aleatoria con la misma probabilidad.
#
# Simule $10$ segundos con un $\Delta t=0.001$ y represéntelo en un gráfico 3D.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

tiempo_tot = 10  
delta_t = 0.001  
num_steps = int(tiempo_tot / delta_t)  
x = np.zeros(num_steps + 1)
y = np.zeros(num_steps + 1)
z = np.zeros(num_steps + 1)

for i in range(1, num_steps + 1):
    delta_x = np.random.choice([-1, 1])
    delta_y = np.random.choice([-1, 1])
    delta_z = np.random.choice([-1, 1])
    

    x[i] = x[i-1] + delta_x * np.sqrt(delta_t)
    y[i] = y[i-1] + delta_y * np.sqrt(delta_t)
    z[i] = z[i-1] + delta_z * np.sqrt(delta_t)
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, linestyle='-')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# #### 2. Apuesta arriesgada
#
# Un jugador, con 20 pesos de capital inicial, decide apostar a un volado (con una moneda perfectamente nivelada) la mitad de su capital si éste es mayor o igual a 6 pesos, de lo contrario, solo 2. Esto es, el capital $C_i$ en cada volado $V_i$ se describe como
# $$
# C_{i+1}=C_i+V_iA_i
# $$
# donde la apuesta es
# $$
# A_i=\left\{\begin{array}{l}
# C_i/2,\quad \mbox{si }C_i\geq 6\\
# 2,\quad \mbox{de lo contrario.}
# \end{array}\right.
# $$
#
# 1. Grafique la evolución del capital hasta quedar en cero.
# 2. Determine el número de volados promedio para quedar en quiebra usando la simulación montecarlo para 10,000 apostadores.
# 3. Muestre un histograma del número de volados.

# %%
import random
import matplotlib.pyplot as plt
def tirar_moneda():
    moneda= random.randint(1,2)
    if moneda==1:
        return True
    else:
        return False 
def apostador(C0):
    C= C0
    num_volados=0
    while C > 0:
        if C>= 6:
            apuesta= C/2
        else:
            apuesta= 2
        resultado= tirar_moneda()
        if resultado== True:
            C+=apuesta
        else:
            C-=apuesta
        num_volados+=1
    return num_volados

# %%
def simulacion_montecarlo(N):
    resultados = []
    for i in range(N):
        resultados.append(apostador(20))
    
    return resultados

# %%
resultados= np.array(simulacion_montecarlo(10000))
promedio= resultados.mean()
print(promedio)
plt.hist(resultados)
# Out:
# 26.0348
# (array([6.477e+03, 2.232e+03, 8.040e+02, 3.110e+02, 1.150e+02, 3.900e+01,
#         1.300e+01, 7.000e+00, 1.000e+00, 1.000e+00]),
#  array([  5. ,  26.4,  47.8,  69.2,  90.6, 112. , 133.4, 154.8, 176.2,
#         197.6, 219. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# En promedio el numero de volados para quedar en quiebra es de 26

# %%
def apostador(C0):
    C= [C0]
    while C[-1] > 0:
        if C[-1]>= 6:
            apuesta= C[-1]/2
        else:
            apuesta= 2
        resultado= tirar_moneda()
        if resultado== True:
            C.append(C[-1]+apuesta)
        else:
            C.append(C[-1]-apuesta)
    return C
plt.plot(apostador(20))
plt.title("Evolución del capital hasta llegar a 0")
# Out:
# Text(0.5, 1.0, 'Evolución del capital hasta llegar a 0')
